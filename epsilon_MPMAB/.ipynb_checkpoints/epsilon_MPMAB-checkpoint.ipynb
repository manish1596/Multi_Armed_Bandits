# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import seaborn as sns
import pandas as pd

# %%
def sample_from_normal_dist(mu, sigma):
    return np.random.normal(mu)

# %%
class MultiArmedBandit:
    def __init__(self, arm_count, time_horizon, ground_truth_means):
        self.K = int(arm_count)
        self.T = int(time_horizon)
        self.curr_t = 0
        self.total_reward = 0
        self.ground_truth_means = ground_truth_means
        self.best_arm_mean = np.max(ground_truth_means)
        self.arm_rewards = np.zeros(self.K)
        self.reward_history = []
        self.regret_history = []
        self.empirical_means = np.zeros(self.K)
        self.arm_sample_count = np.zeros(self.K, dtype = np.int32)
        self.upper_confidence_bounds = np.zeros(self.K)
        self.lower_confidence_bounds = np.zeros(self.K)
    
    def ChooseBestArm(self):
        return np.argmax(self.upper_confidence_bounds)
    
    def UpdateEmpiricalMean(self, a, curr_sample):
        self.curr_t += 1
        self.arm_sample_count[a] += 1
        self.arm_rewards[a] += curr_sample
        self.empirical_means[a] = float(self.arm_rewards[a])/float(self.arm_sample_count[a])
    
    def UpdateConfidenceBounds(self, a):
        T=self.T
        self.upper_confidence_bounds[a] = self.empirical_means[a] + np.sqrt(float(2*np.log(T))/float(self.arm_sample_count[a]))
        self.lower_confidence_bounds[a] = self.empirical_means[a] - np.sqrt(float(2*np.log(T))/float(self.arm_sample_count[a]))
        
    def Update(self, a, curr_sample):
        self.UpdateEmpiricalMean(a, curr_sample)
        self.UpdateConfidenceBounds(a)
    
    def SampleOnce(self):
        for arm in range(self.K):
            curr_sample = np.random.binomial(1, self.ground_truth_means[arm])
            self.Update(arm, curr_sample)
            self.total_reward += curr_sample
            self.reward_history.append(self.total_reward)
            self.regret_history.append(self.best_arm_mean*(len(self.reward_history))-self.total_reward)

    def BanditPlay(self):
        self.SampleOnce()
        for t in range(self.T-self.K):
            curr_arm = self.ChooseBestArm()
            curr_sample = np.random.binomial(1, self.ground_truth_means[curr_arm])
            self.Update(curr_arm, curr_sample)
            self.total_reward += curr_sample
            self.reward_history.append(self.total_reward)
            self.regret_history.append(self.best_arm_mean*(len(self.reward_history))-self.total_reward)

# %%
class MultiplePlayers:
    def __init__(self, a_num_players, a_margin, a_arm_count, a_time_horizon, assumption2=False, assumption2_type="none"):
        self.m_num_players = int(a_num_players)
        self.m_arm_count = int(a_arm_count)
        self.m_margin = float(a_margin)
        self.m_time_horizon = int(a_time_horizon)
        self.m_ground_truth_means_array = np.zeros((self.m_num_players, self.m_arm_count))
        if(assumption2==False):
            seed_ground_truth_means = np.uniform(low=0.0, high=1.0, size=self.m_arm_count)
            for col in range(self.m_arm_count):
                l = max(0.0, seed_ground_truth_means[col]-0.5*self.m_margin)
                h = min(seed_ground_truth_means[col]+0.5*self.m_margin, 1.0)
                self.m_ground_truth_means_array[:,col] = np.random.uniform(low=l, high=h, size=self.m_num_players)
            self.m_players = [MultiArmedBandit(self.m_arm_count, self.m_time_horizon, self.m_ground_truth_means_array[r,:]) for r in range(self.m_num_players)]
        else:
            if(assumption2_type == "epsilon_lesser_half_delta"):
                self.m_ground_truth_means_array[0,-2] = np.random.uniform(low = 0.0, high=1.0-3*self.m_margin)
                self.m_ground_truth_means_array[0,-1] = np.random.uniform(low = self.m_ground_truth_means_array[0,-2]+3*self.m_margin, high=1.0)
                self.m_ground_truth_means_array[0,:-2] = np.random.uniform(low = 0.0, high=self.m_ground_truth_means_array[0,-2], size=(self.m_arm_count-2))
                for col in range(self.m_arm_count):
                    l = max(0.0, self.m_ground_truth_means_array[0,col]-0.5*self.m_margin)
                    h = min(self.m_ground_truth_means_array[0,col]+0.5*self.m_margin, 1.0)
                    self.m_ground_truth_means_array[1:,col] = np.random.uniform(low=l, high=h, size=self.m_num_players-1)
                self.m_players = [MultiArmedBandit(self.m_arm_count, self.m_time_horizon, self.m_ground_truth_means_array[r,:]) for r in range(self.m_num_players)]
            elif(assumption2_type == "epsilon_equal_delta"):
                self.m_ground_truth_means_array[0,-2] = np.random.uniform(low = 0.5*self.m_margin, high=1.0-2*self.m_margin)
                self.m_ground_truth_means_array[0,-1] = self.m_ground_truth_means_array[0,-2]+self.m_margin
                self.m_ground_truth_means_array[0,:-2] = np.random.uniform(low = 0.0, high=self.m_ground_truth_means_array[0,-2]-0.5*self.m_margin, size=(self.m_arm_count-2))
                for col in range(self.m_arm_count):
                    if(col<self.m_arm_count-2):
                        l = max(0.0, self.m_ground_truth_means_array[0,col]-0.5*self.m_margin)
                        h = min(self.m_ground_truth_means_array[0,col]+0.5*self.m_margin, 1.0)
                    else:
                        l = max(0.0, self.m_ground_truth_means_array[0,col]-0.05*self.m_margin)
                        h = min(self.m_ground_truth_means_array[0,col]+0.05*self.m_margin, 1.0)
                    self.m_ground_truth_means_array[1:,col] = np.random.uniform(low=l, high=h, size=self.m_num_players-1)
                self.m_players = [MultiArmedBandit(self.m_arm_count, self.m_time_horizon, self.m_ground_truth_means_array[r,:]) for r in range(self.m_num_players)]
            elif(assumption2_type == "epsilon_greater_twice_delta"):
                seed_ground_truth_means = np.zeros(self.m_arm_count)+0.5
                for col in range(self.m_arm_count):
                    l = max(0.0, seed_ground_truth_means[col]-0.5*self.m_margin)
                    h = min(seed_ground_truth_means[col]+0.5*self.m_margin, 1.0)
                    self.m_ground_truth_means_array[:,col] = np.random.uniform(low=l, high=h, size=self.m_num_players)
                self.m_players = [MultiArmedBandit(self.m_arm_count, self.m_time_horizon, self.m_ground_truth_means_array[r,:]) for r in range(self.m_num_players)]

    def ResetPlayers(self):
        self.m_players = [MultiArmedBandit(self.m_arm_count, self.m_time_horizon, self.m_ground_truth_means_array[r,:]) for r in range(self.m_num_players)]

    def CalculateUCB_width(self, alpha, n, m, X, Y, epsilon):
        T=self.m_time_horizon
        ucb_width = np.sqrt(2*np.log(T)*(float(alpha**2)/float(n) + float((1-alpha)**2)/float(m))) + (1-alpha)*epsilon
        return ucb_width

    def BestWeightedUCB(self, n, m, X, Y, epsilon):
        T=self.m_time_horizon
        A=2*np.log(T)*(float(1)/float(n)+float(1)/float(m))
        B=-4*np.log(T)/float(m)
        C=2*np.log(T)/float(m)
        D=-1*epsilon
        S=float(4*A*C*(np.power(D,2))-np.power(B*D,2))/float(4*np.power(A,3)-4*np.power(A*D,2))
        if(S<0):
            if(self.CalculateUCB_width(0, n, m, X, Y, epsilon) < self.CalculateUCB_width(1, n, m, X, Y, epsilon)):
                UCB_alpha_star =  float(Y)/float(m) + self.CalculateUCB_width(0, n, m, X, Y, epsilon)
            else:
                UCB_alpha_star =  float(X)/float(n) + self.CalculateUCB_width(1, n, m, X, Y, epsilon)
        else:
            if(D>=0):
                alpha_star = -np.sqrt(S) - float(B)/float(2*A)
            else:
                alpha_star = np.sqrt(S) - float(B)/float(2*A)
            if(alpha_star<0):
                alpha_star = 0
            if(alpha_star>1):
                alpha_star = 1
            ucb_width = self.CalculateUCB_width(alpha_star, n, m, X, Y, epsilon)
            UCB_alpha_star = alpha_star*float(X)/float(n) + (1-alpha_star)*float(Y)/float(m) + ucb_width
        return UCB_alpha_star

    def UpdateConfidenceBounds(self, curr_player, weighting):
        for a in range(self.m_arm_count):
            m_other_players = 0
            Y_a = 0
            for p in range(self.m_num_players):
                if(p != curr_player):
                    m_other_players += self.m_players[p].arm_sample_count[a]
                    Y_a += self.m_players[p].arm_rewards[a]
            n = self.m_players[curr_player].arm_sample_count[a]
            X_a = self.m_players[curr_player].arm_rewards[a]
            if(weighting == "best"):
                ucb = self.BestWeightedUCB(n, m_other_players, X_a, Y_a, self.m_margin)
            elif(weighting == "uniform"):
                alpha = float(n)/float(n + m_other_players)
                ucb_width = self.CalculateUCB_width(alpha, n, m_other_players, X_a, Y_a, self.m_margin)
                ucb = alpha*float(X_a)/float(n) + (1-alpha)*float(Y_a)/float(m_other_players) + ucb_width
            elif(weighting == "zero"):
                ucb_width = self.CalculateUCB_width(0, n, m_other_players, X_a, Y_a, self.m_margin)
                ucb = float(Y_a)/float(m_other_players) + ucb_width
            elif(weighting == "one"):
                ucb_width = self.CalculateUCB_width(1, n, m_other_players, X_a, Y_a, self.m_margin)
                ucb = float(X_a)/float(n) + ucb_width
            self.m_players[curr_player].upper_confidence_bounds[a] = ucb

    def IndividualBanditPlay(self):
        for player in self.m_players:
            player.BanditPlay()

    def ConcurrentBanditPlay(self, weighting):
        '''
            All the players play in parallel, weighting is either "best", "uniform", "zero" or "one"
        '''
        for player in self.m_players:
            player.SampleOnce()
        for t in range(self.m_time_horizon-self.m_arm_count):
            for p in range(self.m_num_players):
                p_arm = self.m_players[p].ChooseBestArm()
                p_sample = np.random.binomial(1, self.m_players[p].ground_truth_means[p_arm])
                self.m_players[p].Update(p_arm, p_sample)
                self.m_players[p].total_reward += p_sample
                self.m_players[p].reward_history.append(self.m_players[p].total_reward)
                self.m_players[p].regret_history.append(self.m_players[p].best_arm_mean*(len(self.m_players[p].reward_history))-self.m_players[p].total_reward)
            for p in range(self.m_num_players):
                self.UpdateConfidenceBounds(p, weighting)

    def WarmstartBanditPlay(self, num_warmstart_players, weighting):
        '''
            A given number of players play independently initially and the remaining players warmstart off them
        '''
        for p in range(num_warmstart_players):
            self.m_players[p].BanditPlay()

        for player in self.m_players[num_warmstart_players:]:
            player.SampleOnce()
        for p in range(self.m_num_players):
            self.UpdateConfidenceBounds(p, weighting)
        for t in range(self.m_time_horizon-self.m_arm_count):
            for p in range(num_warmstart_players, self.m_num_players):
                p_arm = self.m_players[p].ChooseBestArm()
                p_sample = np.random.binomial(1, self.m_players[p].ground_truth_means[p_arm])
                self.m_players[p].Update(p_arm, p_sample)
                self.m_players[p].total_reward += p_sample
                self.m_players[p].reward_history.append(self.m_players[p].total_reward)
                self.m_players[p].regret_history.append(self.m_players[p].best_arm_mean*(len(self.m_players[p].reward_history))-self.m_players[p].total_reward)
            for p in range(self.m_num_players):
                self.UpdateConfidenceBounds(p, weighting)

    def CollectiveRegret(self):
        return np.sum(np.array([player.regret_history for player in self.m_players]), axis=0)

# %%
def experiment1():
    '''
    Comparing results with different number of players: M = 2, 10, 100 and under best weighting
    '''
    #M_list = [2, 10, 100]
    M_list = [2, 10]
    K=10
    T=1e4
    epsilon = 0.1

    regret_dict = {}
    for M in M_list:
        players = MultiplePlayers(M, epsilon, K, T, assumption2=True, assumption2_type="epsilon_lesser_half_delta")
        players.IndividualBanditPlay()
        individual_regret = players.CollectiveRegret()
        curr_regret_df = pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':individual_regret, 'type':'individual'})
        players.ResetPlayers()
        players.ConcurrentBanditPlay(weighting="best")
        concurrent_regret = players.CollectiveRegret()
        curr_regret_df = pd.concat([curr_regret_df, pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':concurrent_regret, 'type':'concurrent'})])
        regret_dict[M] = curr_regret_df
        
    return regret_dict

# %%
def experiment2():
    '''
    Comparing results with different relative values of epsilon and delta
    '''
    epsilon_delta_options = ["epsilon_lesser_half_delta", "epsilon_equal_delta", "epsilon_greater_twice_delta"]
    K=10
    T=1e4
    M=10
    epsilon = 0.1

    regret_dict = {}
    for opt in epsilon_delta_options:
        players = MultiplePlayers(M, epsilon, K, T, assumption2=True, assumption2_type=opt)
        players.IndividualBanditPlay()
        individual_regret = players.CollectiveRegret()
        curr_regret_df = pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':individual_regret, 'type':'individual'})
        players.ResetPlayers()
        players.ConcurrentBanditPlay(weighting="best")
        concurrent_regret = players.CollectiveRegret()
        curr_regret_df = pd.concat([curr_regret_df, pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':concurrent_regret, 'type':'concurrent'})])
        regret_dict[opt] = curr_regret_df

    return regret_dict

# %%
def experiment3():
    '''
        Warmstart results
    '''
    K=10
    T=1e4
    M=100
    epsilon=0.1
    warmstart_players = [int(M/2), int(M/4)]

    regret_dict = {}
    for n in warmstart_players:
        players = MultiplePlayers(M, epsilon, K, T, assumption2=True, assumption2_type="epsilon_lesser_half_delta")
        players.IndividualBanditPlay()
        individual_regret = players.CollectiveRegret()
        curr_regret_df = pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':individual_regret, 'type':'individual'})
        players.ResetPlayers()
        players.WarmstartBanditPlay(num_warmstart_players=n, weighting="best")
        warmstart_regret = players.CollectiveRegret()
        curr_regret_df = pd.concat([curr_regret_df, pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':warmstart_regret, 'type':'warmstart'})])
        regret_dict[n] = curr_regret_df
        
    return regret_dict

# %%
def experiment4():
    '''
        Compare different weighting options
    '''
    K=10
    T=1e4
    M=10
    epsilon=0.1
    weighting_options = ["best", "uniform", "one", "zero"]

    regret_dict = {}
    for opt in weighting_options:
        players = MultiplePlayers(M, epsilon, K, T, assumption2=True, assumption2_type="epsilon_lesser_half_delta")
        players.IndividualBanditPlay()
        individual_regret = players.CollectiveRegret()
        curr_regret_df = pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':individual_regret, 'type':'individual'})
        players.ResetPlayers()
        players.ConcurrentBanditPlay(weighting=opt)
        concurrent_regret = players.CollectiveRegret()
        curr_regret_df = pd.concat([curr_regret_df, pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':concurrent_regret, 'type':'concurrent'})])
        regret_dict[opt] = curr_regret_df
        
    return regret_dict

# %%
## Running experiment1

experiment_count = 50
exp1_regret_df_dict = {}
for e in range(experiment_count):
    regret_dict = experiment1()
    for n in regret_dict.keys():
        curr_regrets = regret_dict[n]
        if(n not in exp1_regret_df_dict.keys()):
            exp1_regret_df_dict[n]=curr_regrets
        else:
            exp1_regret_df_dict[n]=pd.concat([exp1_regret_df_dict[n],curr_regrets])
    print("Experiment " + str(e) + " done")

for n in exp1_regret_df_dict.keys():
    sns.relplot(x="time", y="regret", hue="type", kind="line", ci="sd", data=exp1_regret_df_dict[n])
    plt.savefig("./experiment1/num_players_" + str(n) + ".png", dpi=300)
# Out:
# Experiment 0 done
# Experiment 1 done
# Experiment 2 done
# Experiment 3 done
# Experiment 4 done
# Experiment 5 done
# Experiment 6 done
# Experiment 7 done
# Experiment 8 done
# Experiment 9 done
# Experiment 10 done
# Experiment 11 done
# Experiment 12 done
# Experiment 13 done
# Experiment 14 done
# Experiment 15 done
# Experiment 16 done
# Experiment 17 done
# Experiment 18 done
# Experiment 19 done
# Experiment 20 done
# Experiment 21 done
# Experiment 22 done
# Experiment 23 done
# Experiment 24 done
# Experiment 25 done
# Experiment 26 done
# Experiment 27 done
# Experiment 28 done
# Experiment 29 done
# Experiment 30 done
# Experiment 31 done
# Experiment 32 done
# Experiment 33 done
# Experiment 34 done
# Experiment 35 done
# Experiment 36 done
# Experiment 37 done
# Experiment 38 done
# Experiment 39 done
# Experiment 40 done
# Experiment 41 done
# Experiment 42 done
# Experiment 43 done
# Experiment 44 done
# Experiment 45 done
# Experiment 46 done
# Experiment 47 done
# Experiment 48 done
# Experiment 49 done

# %%
## Running experiment2

experiment_count = 50
exp2_regret_df_dict = {}
for e in range(experiment_count):
    regret_dict = experiment2()
    for opt in regret_dict.keys():
        curr_regrets = regret_dict[opt]
        if(opt not in exp2_regret_df_dict.keys()):
            exp2_regret_df_dict[opt]=curr_regrets
        else:
            exp2_regret_df_dict[opt]=pd.concat([exp2_regret_df_dict[opt],curr_regrets])
    print("Experiment " + str(e) + " done")

for opt in exp2_regret_df_dict.keys():
    sns.relplot(x="time", y="regret", hue="type", kind="line", ci="sd", data=exp2_regret_df_dict[opt])
    plt.savefig("./experiment2/" + str(opt) + ".png", dpi=300)
# Out:
# Experiment 0 done
# Experiment 1 done
# Experiment 2 done
# Experiment 3 done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b57fc7a82753> in <module>
#       4 exp2_regret_df_dict = {}
#       5 for e in range(experiment_count):
# ----> 6     regret_dict = experiment2()
#       7     for opt in regret_dict.keys():
#       8         curr_regrets = regret_dict[opt]
#
# <ipython-input-10-022ddca2758d> in experiment2()
#      16         curr_regret_df = pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':individual_regret, 'type':'individual'})
#      17         players.ResetPlayers()
# ---> 18         players.ConcurrentBanditPlay(weighting="best")
#      19         concurrent_regret = players.CollectiveRegret()
#      20         curr_regret_df = pd.concat([curr_regret_df, pd.DataFrame({'time':np.arange(T, dtype=int), 'regret':concurrent_regret, 'type':'concurrent'})])
#
# <ipython-input-6-ff33d6c62535> in ConcurrentBanditPlay(self, weighting)
#     120                 self.m_players[p].regret_history.append(self.m_players[p].best_arm_mean*(len(self.m_players[p].reward_history))-self.m_players[p].total_reward)
#     121             for p in range(self.m_num_players):
# --> 122                 self.UpdateConfidenceBounds(p, weighting)
#     123
#     124     def WarmstartBanditPlay(self, num_warmstart_players, weighting):
#
# <ipython-input-6-ff33d6c62535> in UpdateConfidenceBounds(self, curr_player, weighting)
#      88             X_a = self.m_players[curr_player].arm_rewards[a]
#      89             if(weighting == "best"):
# ---> 90                 ucb = self.BestWeightedUCB(n, m_other_players, X_a, Y_a, self.m_margin)
#      91             elif(weighting == "uniform"):
#      92                 alpha = float(n)/float(n + m_other_players)
#
# <ipython-input-6-ff33d6c62535> in BestWeightedUCB(self, n, m, X, Y, epsilon)
#      73             if(alpha_star>1):
#      74                 alpha_star = 1
# ---> 75             ucb_width = self.CalculateUCB_width(alpha_star, n, m, X, Y, epsilon)
#      76             UCB_alpha_star = alpha_star*float(X)/float(n) + (1-alpha_star)*float(Y)/float(m) + ucb_width
#      77         return UCB_alpha_star
#
# <ipython-input-6-ff33d6c62535> in CalculateUCB_width(self, alpha, n, m, X, Y, epsilon)
#      49     def CalculateUCB_width(self, alpha, n, m, X, Y, epsilon):
#      50         T=self.m_time_horizon
# ---> 51         ucb_width = np.sqrt(2*np.log(T)*(float(alpha**2)/float(n) + float((1-alpha)**2)/float(m))) + (1-alpha)*epsilon
#      52         return ucb_width
#      53
#
# KeyboardInterrupt:

# %%
## Running experiment1

experiment_count = 50
exp3_regret_df_dict = {}
for e in range(experiment_count):
    regret_dict = experiment3()
    for n in regret_dict.keys():
        curr_regrets = regret_dict[n]
        if(n not in exp3_regret_df_dict.keys()):
            exp3_regret_df_dict[n]=curr_regrets
        else:
            exp3_regret_df_dict[n]=pd.concat([exp3_regret_df_dict[n],curr_regrets])
    print("Experiment " + str(e) + " done")

for n in exp3_regret_df_dict.keys():
    sns.relplot(x="time", y="regret", hue="type", kind="line", ci="sd", data=exp3_regret_df_dict[n])
    plt.savefig("./experiment3/num_warmstart_players_" + str(n) + ".png", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bbd6694bb60e> in <module>
# ----> 1 print(all_exp_regret_df_dict)
#
# NameError: name 'all_exp_regret_df_dict' is not defined

# %%
## Running experiment4

experiment_count = 50
exp4_regret_df_dict = {}
for e in range(experiment_count):
    regret_dict = experiment4()
    for opt in regret_dict.keys():
        curr_regrets = regret_dict[opt]
        if(opt not in exp4_regret_df_dict.keys()):
            exp4_regret_df_dict[opt]=curr_regrets
        else:
            exp4_regret_df_dict[opt]=pd.concat([exp4_regret_df_dict[opt],curr_regrets])
    print("Experiment " + str(e) + " done")

for opt in exp4_regret_df_dict.keys():
    sns.relplot(x="time", y="regret", hue="type", kind="line", ci="sd", data=exp4_regret_df_dict[opt])
    plt.savefig("./experiment4/weighting_" + str(opt) + ".png", dpi=300)
